# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/03_linear.ipynb)
#
# # 🟡 Medium: Simple Linear Layer
#
# Implement a fully-connected linear layer: **y = xW^T + b**
#
# ### Signature
# ```python
# class SimpleLinear:
#     def __init__(self, in_features: int, out_features: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - `self.weight`: shape `(out_features, in_features)`, init with `randn * (1/√in_features)`
# - `self.bias`: shape `(out_features,)`, init as zeros
# - Both must have `requires_grad=True`
# - `forward(x)` computes `x @ W^T + b`
# - Do **NOT** use `torch.nn.Linear`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.5 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

class SimpleLinear:
    def __init__(self, in_features: int, out_features: int):
        pass  # Initialize weight and bias
        self.weight=torch.nn.Parameter(torch.randn(out_features,in_features)*(1/math.sqrt(in_features)),requires_grad=True)
        self.bias=torch.nn.Parameter(torch.zeros(out_features,),requires_grad=True)



    def forward(self, x: torch.Tensor) -> torch.Tensor:
        y=x@torch.transpose(self.weight,-1,0)+self.bias
        return y
        pass  # Compute y = x @ W^T + b

# %%
# 🧪 Debug
layer = SimpleLinear(8, 4)
print("W shape:", layer.weight.shape)  # should be (4, 8)
print("b shape:", layer.bias.shape)    # should be (4,)

x = torch.randn(2, 8)
y = layer.forward(x)
print("Output shape:", y.shape)        # should be (2, 4)
# Out:
# W shape: torch.Size([4, 8])
# b shape: torch.Size([4])
# Output shape: torch.Size([2, 4])

# %%
# ✅ SUBMIT
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Weight & bias shape (1.6ms)
#   ✅ [2/3] Forward pass (27.5ms)
#   ✅ [3/3] Gradient flow (5.1ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (34.3ms total)
#   Progress saved. Run status() to see your dashboard.

# %% [markdown]
# # Linear Layer 10 minute practice

# %% [markdown]
# Question
# 1. What does torch.nn.parameter do
# 2. What if I had to initialize this outside rather than initializing this inside
# 3. What is the right way to do transpose ? Difference between X.transpose and x.view

# %% [markdown]
# Answers. Parameters don't have an init function. Initialization is either doone
#
# nn.init.xavier_uniform_(self.weight)
#
# or
#
# with torch.no_grad():
#
#
#     self.weight.normal_(0, std)
#
# ```
# # This is formatted as code
# ```

# %%
import torch
import torch.nn as nn
import math

class Linear(nn.Module):
  def __init__(self,out_features,in_features):
    super().__init__()

    self.weight=nn.Parameter(torch.randn(out_features,in_features)*math.sqrt(1/in_features))
    self.bias=nn.Parameter(torch.zeros(out_features))
  def forward(self,x):
    y=x@self.weight.T+self.bias
    return y
