# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/02_softmax.ipynb)
#
# # 🟢 Easy: Implement Softmax
#
# Implement the **Softmax** function from scratch.
#
# $$\text{softmax}(x_i) = \frac{e^{x_i}}{\sum_j e^{x_j}}$$
#
# ### Signature
# ```python
# def my_softmax(x: torch.Tensor, dim: int = -1) -> torch.Tensor:
#     ...
# ```
#
# ### Rules
# - Do **NOT** use `torch.softmax`, `F.softmax`, or `torch.nn.Softmax`
# - Must be **numerically stable** (hint: subtract `max` before `exp`)
#
# ### Example
# ```
# Input:  tensor([1., 2., 3.])
# Output: tensor([0.0900, 0.2447, 0.6652])  # sums to 1.0
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 816.6 kB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def logsumexp(x: torch.Tensor, dim:int =-1):
    c=torch.max(x,dim=dim, keepdim=True).values
    return c+torch.log(torch.sum(torch.exp(x-c),dim=dim, keepdim=True))


def my_softmax(x: torch.Tensor, dim: int = -1) -> torch.Tensor:
    logsumex=logsumexp(x,dim)
    return torch.exp(x-logsumex)
    pass  # Replace this

# %%
# 🧪 Debug
x = torch.tensor([1.0, 2.0, 3.0])
print("Output:", my_softmax(x, dim=-1))
print("Sum:   ", my_softmax(x, dim=-1).sum())  # should be ~1.0
print("Ref:   ", torch.softmax(x, dim=-1))
# Out:
# Output: tensor([0.0900, 0.2447, 0.6652])
# Sum:    tensor(1.)
# Ref:    tensor([0.0900, 0.2447, 0.6652])

# %%
# ✅ SUBMIT
from torch_judge import check,hint
check("softmax")
# Out:
# 🧪 Testing: Implement Softmax (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Basic 1-D (1.5ms)
#   ✅ [2/3] 2-D along dim=-1 (1.8ms)
#   ✅ [3/3] Numerical stability (0.9ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (4.2ms total)
#   Progress saved. Run status() to see your dashboard.

# %%
hint ("softmax")
# Out:
# 💡 Hint for Implement Softmax:
#    softmax(x)_i = exp(x_i) / sum(exp(x_j)). Subtract max(x) first for numerical stability.

# %%
x=torch.tensor([[1.0, 2.0, 3.0],[1.0, 4.0, 1.0]])
print(logsumexp(x,-1))
print(my_softmax(x))
# Out:
# tensor([3.4076, 4.0949])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3882/4094854606.py in <cell line: 0>()
#       1 x=torch.tensor([[1.0, 2.0, 3.0],[1.0, 4.0, 1.0]])
#       2 print(logsumexp(x,-1))
# ----> 3 print(my_softmax(x))
#
# /tmp/ipykernel_3882/4099730305.py in my_softmax(x, dim)
#       8 def my_softmax(x: torch.Tensor, dim: int = -1) -> torch.Tensor:
#       9     logsumex=logsumexp(x,dim)
# ---> 10     return torch.exp(x-logsumex)
#      11     pass  # Replace this
#
# RuntimeError: The size of tensor a (3) must match the size of tensor b (2) at non-singleton dimension 1
